# %%
import pandas as pd

cpi_df = pd.read_csv(r"C:\Users\Michael\Documents\CSV Files\CPI_By_State.csv")
cpi_df.head()
# Out:
#                      Urban Area  100% Composite Index  13 % Grocery Items  \
# 0  Anniston-Calhoun, County, AL                  91.2               101.2
# 1                      Akron OH                 100.2               105.1
# 2                    Albany, GA                  90.1               108.7
# 3                    Albany, NY                 108.1               105.0
# 4                Alexandria, LA                  95.1                96.0
#
#    29 % Housing  10% Utilities  12 % Transportation  4% Health Care  \
# 0          74.8          111.2                 88.8            89.3
# 1          99.7          107.9                107.1            86.8
# 2          74.8           82.0                 96.6            89.8
# 3         112.6          101.0                102.8           111.7
# 4          92.7           89.9                 97.2            92.9
#
#    32 % Miscalaneous Goods and Services
# 0                                  96.6
# 1                                  96.0
# 2                                  96.8
# 3                                 108.6
# 4                                  98.2

# %%
cpi_df.shape
# Out:
# (327, 8)

# %% [markdown]
# For what we want to do, we only care about the first column (100% Composite Index). Let's make a dictionary where all of the keys are the cities and all of the values are each city's respective 100% CPI.

# %%
cols = ['Urban Area', '100% Composite Index']
cpi_df = cpi_df[cols]
cpi_df.head()
# Out:
#                      Urban Area  100% Composite Index
# 0  Anniston-Calhoun, County, AL                  91.2
# 1                      Akron OH                 100.2
# 2                    Albany, GA                  90.1
# 3                    Albany, NY                 108.1
# 4                Alexandria, LA                  95.1

# %%
cpi_df.dropna()
# Out:
#                                  Urban Area  100% Composite Index
# 0              Anniston-Calhoun, County, AL                  91.2
# 1                                  Akron OH                 100.2
# 2                                Albany, GA                  90.1
# 3                                Albany, NY                 108.1
# 4                            Alexandria, LA                  95.1
# 5                              Amarillo, TX                  89.5
# 6                              Americus, GA                  88.3
# 7                                  Ames, IA                  96.8
# 8                             Anchorage, AK                 128.4
# 9                              Anderson, SC                  91.8
# 10                             Appleton, WI                  93.3
# 11                              Ardmore, OK                  87.3
# 12                            Arlington, TX                  99.3
# 13                            Asheville, NC                 101.1
# 14                              Ashland, OH                  88.5
# 15                              Atlanta, GA                  95.6
# 16                       Auburn-Opelika, AL                  98.9
# 17                     Augusta-Aiken, GA-SC                  93.2
# 18                               Austin, TX                  95.5
# 19                          Bakersfield, CA                 103.4
# 20                            Baltimore, MD                 119.4
# 21                         Baton, Rouge, LA                  96.1
# 22                             Beaufort, SC                 105.2
# 23                             Beaumont, TX                  95.7
# 24                           Bellingham, WA                 113.0
# 25                       Bergen-Passaic, NJ                 131.3
# 26      Bethesda-Gaithersburg-Frederick, MD                 130.5
# 27                           Binghamton, NY                  98.4
# 28                           Birmingham, AL                  90.8
# 29                      Bismarck-Mandan, ND                  95.3
# ..                                      ...                   ...
# 295               Thomasville-Lexington, NC                  89.2
# 296                              Topeka, KS                  91.8
# 297                  Troy-Miami, County, OH                  95.4
# 298              Truckee-Nevada, County, CA                 146.9
# 299                              Tucson, AZ                  96.5
# 300                               Tulsa, OK                  88.4
# 301                              Tupelo, MS                  88.1
# 302                          Tuscaloosa, AL                  94.6
# 303                         Twin, Falls, ID                  91.5
# 304                               Tyler, TX                  96.3
# 305                            Valdosta, GA                  94.1
# 306                           Vancouver, WA                  94.8
# 307           Vero, Beach-Indian, River, FL                  97.4
# 308                                Waco, TX                  88.9
# 309  Washington-Arlington-Alexandria, DC-VA                 140.1
# 310               Waterloo-Cedar, Falls, IA                  91.7
# 311                              Wausau, WI                  96.5
# 312                         Weatherford, TX                  91.4
# 313                      Wichita, Falls, TX                  86.5
# 314                             Wichita, KS                  91.8
# 315           Williamsport-Lycoming, Co, PA                 100.7
# 316                          Wilmington, DE                 105.2
# 317                          Wilmington, NC                  98.8
# 318                       Winchester, VA-WV                 102.3
# 319                       Winston-Salem, NC                  92.4
# 320                             Wooster, OH                  92.6
# 321                              Yakima, WA                  95.8
# 322                        York, County, PA                 102.1
# 323                   Youngstown-Warren, OH                  90.4
# 324                                Yuma, AZ                 101.2
#
# [325 rows x 2 columns]

# %%
cpi_dict = {}
urban_areas = cpi_df['Urban Area']
cpi_series = cpi_df['100% Composite Index']

# %%
urban_areas[0]
# Out:
# 'Anniston-Calhoun, County, AL'

# %%
cpi_series[0]
# Out:
# 91.2

# %%
length = len(cpi_series)
for idx in range(0,length):
    cpi_dict[urban_areas[idx]] = cpi_series[idx]

# %%
cpi_dict
# Out:
# {'Anniston-Calhoun, County, AL': 91.2,
#  'Akron OH': 100.2,
#  'Albany, GA': 90.1,
#  'Albany, NY': 108.1,
#  'Alexandria, LA': 95.1,
#  'Amarillo, TX': 89.5,
#  'Americus, GA': 88.3,
#  'Ames, IA': 96.8,
#  'Anchorage, AK': 128.4,
#  'Anderson, SC': 91.8,
#  'Appleton, WI': 93.3,
#  'Ardmore, OK': 87.3,
#  'Arlington, TX': 99.3,
#  'Asheville, NC': 101.1,
#  'Ashland, OH': 88.5,
#  'Atlanta, GA': 95.6,
#  'Auburn-Opelika, AL': 98.9,
#  'Augusta-Aiken, GA-SC': 93.2,
#  'Austin, TX': 95.5,
#  'Bakersfield, CA': 103.4,
#  'Baltimore, MD': 119.4,
#  'Baton, Rouge, LA': 96.1,
#  'Beaufort, SC': 105.2,
#  'Beaumont, TX': 95.7,
#  'Bellingham, WA': 113.0,
#  'Bergen-Passaic, NJ': 131.3,
#  'Bethesda-Gaithersburg-Frederick, MD': 130.5,
#  'Binghamton, NY': 98.4,
#  'Birmingham, AL': 90.8,
#  'Bismarck-Mandan, ND': 95.3,
#  'Blacksburg, VA': 95.0,
#  'Boise, ID': 97.2,
#  'Boston, MA': 132.5,
#  'Bowling, Green, KY': 90.7,
#  'Bozeman, MT': 102.0,
#  'Bradenton, FL': 95.8,
#  'Brazoria, County, TX': 89.3,
#  'Brownsville, TX': 85.8,
#  'Buffalo, NY': 95.8,
#  'Burlington, IA': 97.0,
#  'Burlington, NC': 94.6,
#  'Burlington-Chittenden, Co, VT': 120.5,
#  'Camden, SC': 97.4,
#  'Cape, Coral-Fort, Myers, FL': 95.6,
#  'Carlsbad, NM': 95.4,
#  'Cedar, City, UT': 88.7,
#  'Cedar, Rapids, IA': 92.0,
#  'Champaign-Urbana, IL': 96.9,
#  'Chapel, Hill, NC': 113.0,
#  'Charleston, WV': 92.7,
#  'Charleston-N, Charleston, SC': 98.3,
#  'Charlotte, NC': 93.2,
#  'Charlottesville, VA': 107.0,
#  'Chattanooga, TN': 91.1,
#  'Cheyenne, WY': 100.5,
#  'Chicago, IL': 116.9,
#  'Cincinnati, OH': 93.8,
#  'Clarksburg, WV': 95.0,
#  'Clarksville, TN': 93.0,
#  'Cleveland, OH': 101.0,
#  'Cleveland, TN': 93.4,
#  'Colorado, Springs, CO': 92.8,
#  'Columbia, MO': 91.8,
#  'Columbia, SC': 100.4,
#  'Columbus, OH': 92.0,
#  'Conroe, TX': 91.4,
#  'Conway, AR': 86.6,
#  'Cookeville, TN': 85.7,
#  'Corpus, Christi, TX': 90.8,
#  'Covington, KY': 87.8,
#  'Dallas, TX': 91.9,
#  'Danville, IL': 91.1,
#  'Dare, County, NC': 107.3,
#  'Davenport-Moline-Rock, Is, IA-IL': 96.8,
#  'Dayton, OH': 91.4,
#  'Decatur, IL': 91.4,
#  'Decatur-Hartselle, AL': 89.2,
#  'Denver, CO': 103.2,
#  'Des, Moines, IA': 90.9,
#  'Detroit, MI': 99.4,
#  'Dodge, City, KS': 89.3,
#  'Dothan, AL': 89.8,
#  'Douglas, GA': 88.6,
#  'Dover, DE': 99.7,
#  'Dubuque, IA': 95.9,
#  'Durham, NC': 96.6,
#  'Dutchess, County, NY': 120.4,
#  'Dyersburg, TN': 88.6,
#  'Eau, Claire, WI': 93.7,
#  'Edmond, OK': 91.6,
#  'El, Paso, TX': 90.4,
#  'Elkhart-Goshen, IN': 94.0,
#  'Enid, OK': 93.6,
#  'Erie, PA': 92.1,
#  'Eugene, OR': 109.8,
#  'Evansville, IN': 96.2,
#  'Everett, WA': 111.3,
#  'Fairbanks, AK': 137.4,
#  'Fargo-Moorhead, ND-MN': 92.7,
#  'Farmington, NM': 97.0,
#  'Fayetteville, AR': 92.1,
#  'Fayetteville, NC': 95.2,
#  'Findlay, OH': 94.3,
#  'Fitchburg-Leominster, MA': 103.3,
#  'Flagstaff, AZ': 114.9,
#  'Florence, AL': 90.2,
#  'Fort, Lauderdale, FL': 115.7,
#  'Fort, Smith, AR': 86.1,
#  'Fort, Wayne-Allen, County, IN': 94.4,
#  'Fort, Worth, TX': 91.1,
#  'Framingham-Natick, MA': 134.5,
#  'Fresno, CA': 117.3,
#  'Gainesville, FL': 99.8,
#  'Galesburg, IL': 93.0,
#  'Garden, City, KS': 89.7,
#  'Glens, Falls, NY': 112.3,
#  'Glenwood, Springs, CO': 124.0,
#  'Grand, Junction, CO': 98.3,
#  'Grand, Rapids, MI': 90.7,
#  'Green, Bay, WI': 95.1,
#  'Greenville, NC': 98.5,
#  'Greenville, SC': 90.3,
#  'Gunnison, CO': 110.0,
#  'Hammond, LA': 95.9,
#  'Hampton, Roads-SE, Virginia, VA': 111.7,
#  'Harlingen, TX': 82.8,
#  'Harrisburg, PA': 99.7,
#  'Harrisonburg, VA': 97.0,
#  'Hartford, CT': 121.8,
#  'Hastings, NE': 93.4,
#  'Hattiesburg, MS': 91.9,
#  'Hays, KS': 89.4,
#  'Hickory, NC': 92.9,
#  'Hilton, Head, Island, SC': 114.1,
#  'Honolulu, HI': 165.7,
#  'Hot, Springs, AR': 93.8,
#  'Houston, TX': 92.2,
#  'Huntsville, AL': 91.2,
#  'Hutchinson, KS': 94.0,
#  'Idaho, Falls, ID': 90.6,
#  'Indiana, County, PA': 93.3,
#  'Indianapolis, IN': 87.2,
#  'Iowa, City, IA': 96.2,
#  'Ithaca, NY': 102.8,
#  'Jackson, MS': 96.9,
#  'Jackson-Madison, County, TN': 90.2,
#  'Jacksonville, FL': 92.9,
#  'Jacksonville, NC': 96.5,
#  'Janesville, WI': 96.2,
#  'Jefferson, City, MO': 92.9,
#  'Johnson, City, TN': 86.7,
#  'Johnstown, PA': 92.9,
#  'Joliet-Will, County, IL': 102.2,
#  'Jonesboro, AR': 88.9,
#  'Joplin, MO': 88.8,
#  'Juneau, AK': 136.5,
#  'Kalamazoo, MI': 91.2,
#  'Kalispell, MT': 98.8,
#  'Kansas, City, MO-KS': 97.8,
#  'Kennewick-Richland-Pasco, WA': 92.6,
#  'Kinston, NC': 93.8,
#  'Knoxville, TN': 89.4,
#  'Kodiak, AK': 128.7,
#  'Lafayette, IN': 98.2,
#  'Lafayette, LA': 99.2,
#  'Lake, Charles, LA': 97.4,
#  'Lake, Havasu, City, AZ': 111.8,
#  'Lancaster, PA': 106.8,
#  'Laramie, WY': 97.0,
#  'Las, Cruces, NM': 100.6,
#  'Las, Vegas, NV': 101.9,
#  'Lawrence, KS': 94.6,
#  'Lawton, OK': 93.8,
#  'Lexington, KY': 92.8,
#  'Lexington-Buena, Vista-Rockbridge, VA': 93.7,
#  'Lima, OH': 93.1,
#  'Little, Rock-North, Little, Rock, AR': 96.5,
#  'Logan, UT': 95.6,
#  'Los, Alamos, NM': 109.7,
#  'Los, Angeles-Long, Beach, CA': 136.4,
#  'Louisville, KY': 87.7,
#  'Loveland, CO': 91.0,
#  'Lubbock, TX': 89.1,
#  'Lufkin, TX': 92.4,
#  'Lynchburg, VA': 95.1,
#  'Manchester, NH': 116.8,
#  'Manhattan, KS': 95.0,
#  'Mankato, MN': 93.0,
#  'Marietta, GA': 94.8,
#  'Marion-McDowell, County, NC': 92.1,
#  'Marshfield, WI': 94.2,
#  'Martinsburg-Berkeley, County, WV': 89.6,
#  'Martinsville-Henry, County, VA': 87.1,
#  'Mason, City, IA': 89.1,
#  'McAllen, TX': 85.0,
#  'Memphis, TN': 88.2,
#  'Miami-Dade, County, FL': 106.0,
#  'Middlesex-Monmouth, NJ': 124.8,
#  'Midland, TX': 93.2,
#  'Milwaukee-Waukesha, WI': 101.9,
#  'Minneapolis, MN': 111.0,
#  'Minot, ND': 99.9,
#  'Missoula, MT': 99.4,
#  'Mobile, AL': 92.7,
#  'Monroe, LA': 92.7,
#  'Montgomery, AL': 99.2,
#  'Morgantown, WV': 100.6,
#  'Morristown, TN': 90.9,
#  'Muncie, IN': 91.0,
#  'Murfreesboro-Smyrna, TN': 88.2,
#  'Muskogee, OK': 86.0,
#  'Myrtle, Beach, SC': 95.2,
#  'Nacogdoches, TX': 92.5,
#  'Nashville-Franklin, TN': 88.9,
#  'Nassau, County, NY': 145.7,
#  'New, Haven, CT': 122.1,
#  'New, York, (Brooklyn), NY': 181.7,
#  'New, York, (Manhattan), NY': 216.7,
#  'New, York, (Queens), NY': 159.0,
#  'Newark-Elizabeth, NJ': 129.7,
#  'Norman, OK': 94.4,
#  'Oakland, CA': 139.1,
#  'Odessa, TX': 90.9,
#  'Oklahoma, City, OK': 91.7,
#  'Olympia, WA': 104.1,
#  'Omaha, NE': 88.3,
#  'Orange, County, CA': 146.4,
#  'Orlando, FL': 97.8,
#  'Paducah, KY': 87.3,
#  'Palm, Springs, CA': 121.8,
#  'Panama, City, FL': 99.4,
#  'Paris, TX': 88.9,
#  'Pascagoula, MS': 92.3,
#  'Peoria, IL': 96.3,
#  'Philadelphia, PA': 126.5,
#  'Phoenix, AZ': 100.7,
#  'Pittsburgh, PA': 91.5,
#  'Pittsfield, MA': 110.6,
#  'Plano, TX': 97.4,
#  'Plattsburgh, NY': 100.1,
#  'Ponca, City, OK': 90.0,
#  'Portland, ME': 116.5,
#  'Portland, OR': 111.3,
#  'Prescott-Prescott, Valley, AZ': 103.7,
#  'Providence, RI': 123.3,
#  'Pryor, Creek, OK': 84.5,
#  'Pueblo, CO': 85.6,
#  'Quincy, IL': 95.5,
#  'Raleigh, NC': 98.2,
#  'Reno-Sparks, NV': 101.1,
#  'Richmond, IN': 90.8,
#  'Richmond, VA': 104.5,
#  'Rio, Rancho, NM': 95.1,
#  'Riverside, City, CA': 112.5,
#  'Roanoke, VA': 94.1,
#  'Rochester, MN': 99.2,
#  'Rochester, NY': 100.0,
#  'Rockford, IL': 92.4,
#  'Roswell, NM': 95.9,
#  'Round, Rock, TX': 89.7,
#  'Sacramento, CA': 116.2,
#  'Salina, KS': 86.9,
#  'Salt, Lake, City, UT': 100.6,
#  'San, Angelo, TX': 92.4,
#  'San, Antonio, TX': 95.7,
#  'San, Diego, CA': 132.3,
#  'San, Francisco, CA': 164.0,
#  'San, Jose, CA': 156.1,
#  'San, Marcos, TX': 94.8,
#  'Sarasota, FL': 101.5,
#  'Savannah, GA': 93.5,
#  'Seattle, WA': 121.4,
#  'Seguin, TX': 90.7,
#  'Sheboygan, WI': 101.4,
#  'Shreveport-Bossier, City, LA': 95.3,
#  'Sierra, Vista, AZ': 97.9,
#  'Sioux, Falls, SD': 94.1,
#  'Slidell-St., Tammany, Parish, LA': 97.0,
#  'South, Bend, IN': 91.9,
#  'Spokane, WA': 93.9,
#  'Springfield, IL': 85.8,
#  'Springfield, MO': 88.0,
#  'St., Cloud, MN': 98.3,
#  'St., George, UT': 95.9,
#  'St., Joseph, MO': 92.3,
#  'St., Louis, MO-IL': 90.4,
#  'St., Paul, MN': 110.0,
#  'Stamford, CT': 146.9,
#  'Staunton-Augusta, County, VA': 96.2,
#  'Stillwater, OK': 90.1,
#  'Sumter, SC': 96.3,
#  'Syracuse, NY': 101.5,
#  'Tacoma, WA': 109.5,
#  'Tampa, FL': 92.4,
#  'Temple, TX': 87.4,
#  'Thomasville-Lexington, NC': 89.2,
#  'Topeka, KS': 91.8,
#  'Troy-Miami, County, OH': 95.4,
#  'Truckee-Nevada, County, CA': 146.9,
#  'Tucson, AZ': 96.5,
#  'Tulsa, OK': 88.4,
#  'Tupelo, MS': 88.1,
#  'Tuscaloosa, AL': 94.6,
#  'Twin, Falls, ID': 91.5,
#  'Tyler, TX': 96.3,
#  'Valdosta, GA': 94.1,
#  'Vancouver, WA': 94.8,
#  'Vero, Beach-Indian, River, FL': 97.4,
#  'Waco, TX': 88.9,
#  'Washington-Arlington-Alexandria, DC-VA': 140.1,
#  'Waterloo-Cedar, Falls, IA': 91.7,
#  'Wausau, WI': 96.5,
#  'Weatherford, TX': 91.4,
#  'Wichita, Falls, TX': 86.5,
#  'Wichita, KS': 91.8,
#  'Williamsport-Lycoming, Co, PA': 100.7,
#  'Wilmington, DE': 105.2,
#  'Wilmington, NC': 98.8,
#  'Winchester, VA-WV': 102.3,
#  'Winston-Salem, NC': 92.4,
#  'Wooster, OH': 92.6,
#  'Yakima, WA': 95.8,
#  'York, County, PA': 102.1,
#  'Youngstown-Warren, OH': 90.4,
#  'Yuma, AZ': 101.2,
#  'Source: C2ER, Arlington, VA, ACCRA Cost of Living Index, Annual Average 2010 (copyright).': nan,
#  'Internet release date: 9/30/2011': nan}

# %%
def equivalent_income(current_state, new_state, current_income):
    equiv_income = current_income * (cpi_dict[new_state]/cpi_dict[current_state])
    return equiv_income

# %%
san_fran_income = equivalent_income("Troy-Miami, County, OH", "San, Francisco, CA", 50000 )
san_fran_income
# Out:
# 85953.8784067086

# %% [markdown]
# I knew the cost of living was insane in San Fran but geez. Regarding the dataset, some of the states have more commas than necessary. The very first state in the dataset doesn't have a comma at all. This incongruence makes using the equivalent income function a bit of an annoyance. Let's set all the states to the same format.

# %%
Link to dataset: https://www2.census.gov/library/publications/2011/compendia/statab/131ed/tables/12s0728.xls

# %%
cpi_df['Urban Area'] = cpi_df['Urban Area'].str.replace(",", "")
urban_areas = cpi_df['Urban Area']

# %%
length = len(cpi_series)
cpi_dict = {}
for idx in range(0,length):
    cpi_dict[urban_areas[idx]] = cpi_series[idx]

# %%
cpi_dict
# Out:
# {'Anniston-Calhoun County AL': 91.2,
#  'Akron OH': 100.2,
#  'Albany GA': 90.1,
#  'Albany NY': 108.1,
#  'Alexandria LA': 95.1,
#  'Amarillo TX': 89.5,
#  'Americus GA': 88.3,
#  'Ames IA': 96.8,
#  'Anchorage AK': 128.4,
#  'Anderson SC': 91.8,
#  'Appleton WI': 93.3,
#  'Ardmore OK': 87.3,
#  'Arlington TX': 99.3,
#  'Asheville NC': 101.1,
#  'Ashland OH': 88.5,
#  'Atlanta GA': 95.6,
#  'Auburn-Opelika AL': 98.9,
#  'Augusta-Aiken GA-SC': 93.2,
#  'Austin TX': 95.5,
#  'Bakersfield CA': 103.4,
#  'Baltimore MD': 119.4,
#  'Baton Rouge LA': 96.1,
#  'Beaufort SC': 105.2,
#  'Beaumont TX': 95.7,
#  'Bellingham WA': 113.0,
#  'Bergen-Passaic NJ': 131.3,
#  'Bethesda-Gaithersburg-Frederick MD': 130.5,
#  'Binghamton NY': 98.4,
#  'Birmingham AL': 90.8,
#  'Bismarck-Mandan ND': 95.3,
#  'Blacksburg VA': 95.0,
#  'Boise ID': 97.2,
#  'Boston MA': 132.5,
#  'Bowling Green KY': 90.7,
#  'Bozeman MT': 102.0,
#  'Bradenton FL': 95.8,
#  'Brazoria County TX': 89.3,
#  'Brownsville TX': 85.8,
#  'Buffalo NY': 95.8,
#  'Burlington IA': 97.0,
#  'Burlington NC': 94.6,
#  'Burlington-Chittenden Co VT': 120.5,
#  'Camden SC': 97.4,
#  'Cape Coral-Fort Myers FL': 95.6,
#  'Carlsbad NM': 95.4,
#  'Cedar City UT': 88.7,
#  'Cedar Rapids IA': 92.0,
#  'Champaign-Urbana IL': 96.9,
#  'Chapel Hill NC': 113.0,
#  'Charleston WV': 92.7,
#  'Charleston-N Charleston SC': 98.3,
#  'Charlotte NC': 93.2,
#  'Charlottesville VA': 107.0,
#  'Chattanooga TN': 91.1,
#  'Cheyenne WY': 100.5,
#  'Chicago IL': 116.9,
#  'Cincinnati OH': 93.8,
#  'Clarksburg WV': 95.0,
#  'Clarksville TN': 93.0,
#  'Cleveland OH': 101.0,
#  'Cleveland TN': 93.4,
#  'Colorado Springs CO': 92.8,
#  'Columbia MO': 91.8,
#  'Columbia SC': 100.4,
#  'Columbus OH': 92.0,
#  'Conroe TX': 91.4,
#  'Conway AR': 86.6,
#  'Cookeville TN': 85.7,
#  'Corpus Christi TX': 90.8,
#  'Covington KY': 87.8,
#  'Dallas TX': 91.9,
#  'Danville IL': 91.1,
#  'Dare County NC': 107.3,
#  'Davenport-Moline-Rock Is IA-IL': 96.8,
#  'Dayton OH': 91.4,
#  'Decatur IL': 91.4,
#  'Decatur-Hartselle AL': 89.2,
#  'Denver CO': 103.2,
#  'Des Moines IA': 90.9,
#  'Detroit MI': 99.4,
#  'Dodge City KS': 89.3,
#  'Dothan AL': 89.8,
#  'Douglas GA': 88.6,
#  'Dover DE': 99.7,
#  'Dubuque IA': 95.9,
#  'Durham NC': 96.6,
#  'Dutchess County NY': 120.4,
#  'Dyersburg TN': 88.6,
#  'Eau Claire WI': 93.7,
#  'Edmond OK': 91.6,
#  'El Paso TX': 90.4,
#  'Elkhart-Goshen IN': 94.0,
#  'Enid OK': 93.6,
#  'Erie PA': 92.1,
#  'Eugene OR': 109.8,
#  'Evansville IN': 96.2,
#  'Everett WA': 111.3,
#  'Fairbanks AK': 137.4,
#  'Fargo-Moorhead ND-MN': 92.7,
#  'Farmington NM': 97.0,
#  'Fayetteville AR': 92.1,
#  'Fayetteville NC': 95.2,
#  'Findlay OH': 94.3,
#  'Fitchburg-Leominster MA': 103.3,
#  'Flagstaff AZ': 114.9,
#  'Florence AL': 90.2,
#  'Fort Lauderdale FL': 115.7,
#  'Fort Smith AR': 86.1,
#  'Fort Wayne-Allen County IN': 94.4,
#  'Fort Worth TX': 91.1,
#  'Framingham-Natick MA': 134.5,
#  'Fresno CA': 117.3,
#  'Gainesville FL': 99.8,
#  'Galesburg IL': 93.0,
#  'Garden City KS': 89.7,
#  'Glens Falls NY': 112.3,
#  'Glenwood Springs CO': 124.0,
#  'Grand Junction CO': 98.3,
#  'Grand Rapids MI': 90.7,
#  'Green Bay WI': 95.1,
#  'Greenville NC': 98.5,
#  'Greenville SC': 90.3,
#  'Gunnison CO': 110.0,
#  'Hammond LA': 95.9,
#  'Hampton Roads-SE Virginia VA': 111.7,
#  'Harlingen TX': 82.8,
#  'Harrisburg PA': 99.7,
#  'Harrisonburg VA': 97.0,
#  'Hartford CT': 121.8,
#  'Hastings NE': 93.4,
#  'Hattiesburg MS': 91.9,
#  'Hays KS': 89.4,
#  'Hickory NC': 92.9,
#  'Hilton Head Island SC': 114.1,
#  'Honolulu HI': 165.7,
#  'Hot Springs AR': 93.8,
#  'Houston TX': 92.2,
#  'Huntsville AL': 91.2,
#  'Hutchinson KS': 94.0,
#  'Idaho Falls ID': 90.6,
#  'Indiana County PA': 93.3,
#  'Indianapolis IN': 87.2,
#  'Iowa City IA': 96.2,
#  'Ithaca NY': 102.8,
#  'Jackson MS': 96.9,
#  'Jackson-Madison County TN': 90.2,
#  'Jacksonville FL': 92.9,
#  'Jacksonville NC': 96.5,
#  'Janesville WI': 96.2,
#  'Jefferson City MO': 92.9,
#  'Johnson City TN': 86.7,
#  'Johnstown PA': 92.9,
#  'Joliet-Will County IL': 102.2,
#  'Jonesboro AR': 88.9,
#  'Joplin MO': 88.8,
#  'Juneau AK': 136.5,
#  'Kalamazoo MI': 91.2,
#  'Kalispell MT': 98.8,
#  'Kansas City MO-KS': 97.8,
#  'Kennewick-Richland-Pasco WA': 92.6,
#  'Kinston NC': 93.8,
#  'Knoxville TN': 89.4,
#  'Kodiak AK': 128.7,
#  'Lafayette IN': 98.2,
#  'Lafayette LA': 99.2,
#  'Lake Charles LA': 97.4,
#  'Lake Havasu City AZ': 111.8,
#  'Lancaster PA': 106.8,
#  'Laramie WY': 97.0,
#  'Las Cruces NM': 100.6,
#  'Las Vegas NV': 101.9,
#  'Lawrence KS': 94.6,
#  'Lawton OK': 93.8,
#  'Lexington KY': 92.8,
#  'Lexington-Buena Vista-Rockbridge VA': 93.7,
#  'Lima OH': 93.1,
#  'Little Rock-North Little Rock AR': 96.5,
#  'Logan UT': 95.6,
#  'Los Alamos NM': 109.7,
#  'Los Angeles-Long Beach CA': 136.4,
#  'Louisville KY': 87.7,
#  'Loveland CO': 91.0,
#  'Lubbock TX': 89.1,
#  'Lufkin TX': 92.4,
#  'Lynchburg VA': 95.1,
#  'Manchester NH': 116.8,
#  'Manhattan KS': 95.0,
#  'Mankato MN': 93.0,
#  'Marietta GA': 94.8,
#  'Marion-McDowell County NC': 92.1,
#  'Marshfield WI': 94.2,
#  'Martinsburg-Berkeley County WV': 89.6,
#  'Martinsville-Henry County VA': 87.1,
#  'Mason City IA': 89.1,
#  'McAllen TX': 85.0,
#  'Memphis TN': 88.2,
#  'Miami-Dade County FL': 106.0,
#  'Middlesex-Monmouth NJ': 124.8,
#  'Midland TX': 93.2,
#  'Milwaukee-Waukesha WI': 101.9,
#  'Minneapolis MN': 111.0,
#  'Minot ND': 99.9,
#  'Missoula MT': 99.4,
#  'Mobile AL': 92.7,
#  'Monroe LA': 92.7,
#  'Montgomery AL': 99.2,
#  'Morgantown WV': 100.6,
#  'Morristown TN': 90.9,
#  'Muncie IN': 91.0,
#  'Murfreesboro-Smyrna TN': 88.2,
#  'Muskogee OK': 86.0,
#  'Myrtle Beach SC': 95.2,
#  'Nacogdoches TX': 92.5,
#  'Nashville-Franklin TN': 88.9,
#  'Nassau County NY': 145.7,
#  'New Haven CT': 122.1,
#  'New York (Brooklyn) NY': 181.7,
#  'New York (Manhattan) NY': 216.7,
#  'New York (Queens) NY': 159.0,
#  'Newark-Elizabeth NJ': 129.7,
#  'Norman OK': 94.4,
#  'Oakland CA': 139.1,
#  'Odessa TX': 90.9,
#  'Oklahoma City OK': 91.7,
#  'Olympia WA': 104.1,
#  'Omaha NE': 88.3,
#  'Orange County CA': 146.4,
#  'Orlando FL': 97.8,
#  'Paducah KY': 87.3,
#  'Palm Springs CA': 121.8,
#  'Panama City FL': 99.4,
#  'Paris TX': 88.9,
#  'Pascagoula MS': 92.3,
#  'Peoria IL': 96.3,
#  'Philadelphia PA': 126.5,
#  'Phoenix AZ': 100.7,
#  'Pittsburgh PA': 91.5,
#  'Pittsfield MA': 110.6,
#  'Plano TX': 97.4,
#  'Plattsburgh NY': 100.1,
#  'Ponca City OK': 90.0,
#  'Portland ME': 116.5,
#  'Portland OR': 111.3,
#  'Prescott-Prescott Valley AZ': 103.7,
#  'Providence RI': 123.3,
#  'Pryor Creek OK': 84.5,
#  'Pueblo CO': 85.6,
#  'Quincy IL': 95.5,
#  'Raleigh NC': 98.2,
#  'Reno-Sparks NV': 101.1,
#  'Richmond IN': 90.8,
#  'Richmond VA': 104.5,
#  'Rio Rancho NM': 95.1,
#  'Riverside City CA': 112.5,
#  'Roanoke VA': 94.1,
#  'Rochester MN': 99.2,
#  'Rochester NY': 100.0,
#  'Rockford IL': 92.4,
#  'Roswell NM': 95.9,
#  'Round Rock TX': 89.7,
#  'Sacramento CA': 116.2,
#  'Salina KS': 86.9,
#  'Salt Lake City UT': 100.6,
#  'San Angelo TX': 92.4,
#  'San Antonio TX': 95.7,
#  'San Diego CA': 132.3,
#  'San Francisco CA': 164.0,
#  'San Jose CA': 156.1,
#  'San Marcos TX': 94.8,
#  'Sarasota FL': 101.5,
#  'Savannah GA': 93.5,
#  'Seattle WA': 121.4,
#  'Seguin TX': 90.7,
#  'Sheboygan WI': 101.4,
#  'Shreveport-Bossier City LA': 95.3,
#  'Sierra Vista AZ': 97.9,
#  'Sioux Falls SD': 94.1,
#  'Slidell-St. Tammany Parish LA': 97.0,
#  'South Bend IN': 91.9,
#  'Spokane WA': 93.9,
#  'Springfield IL': 85.8,
#  'Springfield MO': 88.0,
#  'St. Cloud MN': 98.3,
#  'St. George UT': 95.9,
#  'St. Joseph MO': 92.3,
#  'St. Louis MO-IL': 90.4,
#  'St. Paul MN': 110.0,
#  'Stamford CT': 146.9,
#  'Staunton-Augusta County VA': 96.2,
#  'Stillwater OK': 90.1,
#  'Sumter SC': 96.3,
#  'Syracuse NY': 101.5,
#  'Tacoma WA': 109.5,
#  'Tampa FL': 92.4,
#  'Temple TX': 87.4,
#  'Thomasville-Lexington NC': 89.2,
#  'Topeka KS': 91.8,
#  'Troy-Miami County OH': 95.4,
#  'Truckee-Nevada County CA': 146.9,
#  'Tucson AZ': 96.5,
#  'Tulsa OK': 88.4,
#  'Tupelo MS': 88.1,
#  'Tuscaloosa AL': 94.6,
#  'Twin Falls ID': 91.5,
#  'Tyler TX': 96.3,
#  'Valdosta GA': 94.1,
#  'Vancouver WA': 94.8,
#  'Vero Beach-Indian River FL': 97.4,
#  'Waco TX': 88.9,
#  'Washington-Arlington-Alexandria DC-VA': 140.1,
#  'Waterloo-Cedar Falls IA': 91.7,
#  'Wausau WI': 96.5,
#  'Weatherford TX': 91.4,
#  'Wichita Falls TX': 86.5,
#  'Wichita KS': 91.8,
#  'Williamsport-Lycoming Co PA': 100.7,
#  'Wilmington DE': 105.2,
#  'Wilmington NC': 98.8,
#  'Winchester VA-WV': 102.3,
#  'Winston-Salem NC': 92.4,
#  'Wooster OH': 92.6,
#  'Yakima WA': 95.8,
#  'York County PA': 102.1,
#  'Youngstown-Warren OH': 90.4,
#  'Yuma AZ': 101.2,
#  'Source: C2ER Arlington VA ACCRA Cost of Living Index Annual Average 2010 (copyright).': nan,
#  'Internet release date: 9/30/2011': nan}

# %%
columbus_income = equivalent_income("Troy-Miami County OH", "Columbus OH", 50000)
columbus_income
# Out:
# 48218.02935010482

# %% [markdown]
# I found this interesting. I assumed that the cost of living in Columbus would be greater than that of Troy. This dataset is from 2011, so things could have changed. Let's compare the CPIs of the two areas.

# %%
cpi_dict["Troy-Miami County OH"]
# Out:
# 95.4

# %%
cpi_dict["Columbus OH"]
# Out:
# 92.0

# %% [markdown]
# So the CPI for Columbus is indeed lower than the one for Troy. As stated before, this dataset is from 2011. I'll look into finding a more up-to-date dataset in the future. For now, we can play around with the function.

# %%
columbia_income = equivalent_income("Troy-Miami County OH", "Columbia SC", 50000)
columbia_income
# Out:
# 52620.54507337526
